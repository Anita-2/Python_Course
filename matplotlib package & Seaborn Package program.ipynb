# %% [markdown]
# # Matplotlib Package

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np

# %%
x=np.linspace(10,20,8)   #linear elements

# %%
y=x**2

# %%
y
# Out:
# array([100.        , 130.6122449 , 165.30612245, 204.08163265,
#        246.93877551, 293.87755102, 344.89795918, 400.        ])

# %%
plt.plot(x,y,"r")

# %%
plt.plot(x, y, 'bo')

# %%
help(plt.plot)    #getting help
# Out:
# Help on function plot in module matplotlib.pyplot:
#
# plot(*args, scalex=True, scaley=True, data=None, **kwargs)
#     Plot y versus x as lines and/or markers.
#
#     Call signatures::
#
#         plot([x], y, [fmt], *, data=None, **kwargs)
#         plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)
#
#     The coordinates of the points or line nodes are given by *x*, *y*.
#
#     The optional parameter *fmt* is a convenient way for defining basic
#     formatting like color, marker and linestyle. It's a shortcut string
#     notation described in the *Notes* section below.
#
#     >>> plot(x, y)        # plot x and y using default line style and color
#     >>> plot(x, y, 'bo')  # plot x and y using blue circle markers
#     >>> plot(y)           # plot y using x as index array 0..N-1
#     >>> plot(y, 'r+')     # ditto, but with red plusses
#
#     You can use `.Line2D` properties as keyword arguments for more
# ...

# %%
plt.plot(x,y, 'r+')

# %%
plt.plot(x,y, 'g*')

# %%
plt.plot(x,y, 'g*')
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.title("X vs Y")
# Out:
# Text(0.5, 1.0, 'X vs Y')

# %%
plt.subplot(1,2,1)   #1 row 2 columns, 1 is for first plot
# Out:
# <AxesSubplot:>

# %%
plt.subplot(1,2,1)  #dividing canvas area 
plt.plot(x,y,"r")

# %%
plt.subplot(1,2,1)
plt.plot(x,y,"r--")
plt.xlabel("X")
plt.ylabel("Y")
plt.subplot(1,2,2)
plt.plot(y,x,"p")
plt.xlabel("X")
plt.ylabel("Y")
# Out:
# Text(0, 0.5, 'Y')

# %%
plt.subplot(1,3,1)
plt.plot(x,y,"r--")

plt.subplot(1,3,2)
plt.plot(y,x,"p")

plt.subplot(1,3,3)

plt.plot(x,x**2,"g+")

# %%
plt.subplot(2,2,1)
plt.plot(x,y,"r--")

plt.subplot(2,2,2)
plt.plot(y,x,"bo")

plt.subplot(2,2,3)

plt.plot(x,x**2,"g+")
plt.subplot(2,2,4)

plt.plot(x,x**2,"y")

# %%
#creating object
fig=plt.figure()

# %%
fig

# %%
type(fig)
# Out:
# matplotlib.figure.Figure

# %%
fig=plt.figure()
axes=fig.add_axes([0.1,0.1,0.9,0.9])#left,bottom,width and height

# %%
fig=plt.figure()
axes=fig.add_axes([0.1,0.1,0.9,0.9])
axes.plot(x,y,"b")
axes.set_xlabel("X axis")
axes.set_ylabel("Y axis")
axes.set_title("X vs Y")
# Out:
# Text(0.5, 1.0, 'X vs Y')

# %%
fig=plt.figure()
axes=fig.add_axes([0.1,0.1,0.9,0.9])
axes2=fig.add_axes([0.2,0.6,0.4,0.2])
axes.plot(x,y,"b")
axes.set_xlabel("X axis")
axes.set_ylabel("Y axis")
axes.set_title("X vs Y")

axes2.plot(y,x,"r")
axes2.set_xlabel("X axis")
axes2.set_ylabel("Y axis")
axes2.set_title("X vs Y")
# Out:
# Text(0.5, 1.0, 'X vs Y')

# %%
##Subplots
fig,axes=plt.subplots()
axes.plot(x,y,"g")
axes.set_xlabel("X axis")
axes.set_ylabel("Y axis")
axes.set_title("X vs Y")
# Out:
# Text(0.5, 1.0, 'X vs Y')

# %%
fig,axes=plt.subplots(nrows=1,ncols=2)

# %%
fig

# %%
axes
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>], dtype=object)

# %%
for v in axes:
    v.plot(x,y,"r")

# %%
fig

# %%
fig,axes=plt.subplots(nrows=4,ncols=4)

# %%
axes
# Out:
# array([[<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]],
#       dtype=object)

# %%
for v,z in axes:
    v[].plot(x,y,"r")
    z.plot(x,y,"b")
# Out:
#   File "<ipython-input-76-7e4b71ec1f3e>", line 2
#     v[].plot(x,y,"r")
#       ^
# SyntaxError: invalid syntax

# %%
fig=plt.figure(figsize=(10,6),dpi=200)

# %%
fig,axes=plt.subplots(figsize=(5,5))
axes.plot(x,y,"r")
fig.savefig("graph1.png",dpi=500)

# %%
pwd
# Out:
# 'C:\\Users\\admin'

# %%
fig=plt.figure()
axis=fig.add_axes([0.4,0.4,0.8,0.8])
axis.plot(x,y,label="X and Y")
axis.plot(x,y**2,label="X and Y**2")
axis.legend(loc=5)

# %%
fig,axes=plt.subplots()
axes.plot(x,y,"blue")
axes.plot(x,y**2,"g")

# %%
plt.scatter(x,y)

# %%
plt.hist(np.random.randint(10,100,5))
# Out:
# (array([1., 0., 0., 0., 0., 1., 0., 0., 1., 2.]),
#  array([12. , 20.6, 29.2, 37.8, 46.4, 55. , 63.6, 72.2, 80.8, 89.4, 98. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(np.random.randn(25).reshape(5,5))
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1efeb46c4f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1efeb46cbb0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1efeb46c190>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1efeb4782b0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1efeb478610>,
# ...
#  'means': []}

# %% [markdown]
# # seaboarn package

# %%
import seaborn as sns

# %%
#data visualization, data analytics, cufflinks plotly

# %%
tips = sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.load_dataset("tips")
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips  #dataframe
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
type(tips)
# Out:
# pandas.core.frame.DataFrame

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips[:]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips['total_bill']  #series---ndarray--
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
type(tips.total_bill)
# Out:
# pandas.core.series.Series

# %%
sns.distplot(tips['total_bill'],kde=True)  #kernel density estimation
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.distplot(tips['total_bill'],kde_kws={"color": "k", "lw": 5, "label": "KDE"})
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='scatter',color='red',height=6,)

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='hex',color='red',height=6,)

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='kde',color='red',height=6)

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='reg',color='blue',height=6,)

# %%
#Linear Regression- best fit line always passes through dense area ...this line is plotted in a such way that distance 
#from all points with line is as minimum as possible
#residual-error should be as minimum as possible-error

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='resid',color='red',height=6,)

# %%
sns.jointplot(x='total_bill',y='tip',data=tips,kind='hist',color='purple',height=6,)

# %%
sns.pairplot(tips)  #pairing with every numerical column

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.pairplot(tips,hue='smoker')

# %%
sns.pairplot(tips,hue='smoker',palette='coolwarm')

# %%
sns.pairplot(tips,hue='smoker',palette='Set1')

# %%
sns.pairplot(tips,hue='sex',palette='Set1')

# %%
sns.pairplot(tips,hue='sex',palette='Set2')

# %%
sns.rugplot(tips['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.kdeplot(tips['total_bill'])
sns.rugplot(tips['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.boxplot(x="day",y="total_bill",data=tips)  #viscurse plot& box plot
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x="day",y="total_bill",data=tips,orient="v")
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(data=tips,orient="h")
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(x='day',y='total_bill',data=tips,hue='sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x='day',y='total_bill',data=tips,hue='sex',palette="Set2")
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x='day',y='total_bill',data=tips,hue='sex',palette="Set2",dodge="True")
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
#violin plot  #distribution of quantative data

# %%
sns.violinplot(x="day",y="total_bill",data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="day",y="total_bill",data=tips,hue="smoker")
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="day",y="total_bill",data=tips,hue="smoker",split=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
#stripplot

# %%
sns.stripplot(x="sex",y="total_bill",data=tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.stripplot(x="day",y="total_bill",data=tips,jitter=True,edgecolor='green',hue="smoker")
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x="day",y="total_bill",data=tips,jitter=True,edgecolor='green',hue="smoker", dodge=True)  #doge-seperate srip for hue
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x="day",y="total_bill",data=tips,jitter=True,edgecolor='green',hue="sex", dodge=True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
#swarm plot

# %%
sns.swarmplot(x="day",y="total_bill",data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x="day",y="total_bill",data=tips,palette='Set1',hue="sex", dodge=True)
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 5.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x="day",y="total_bill",data=tips,palette="rainbow",color="black",size=3)
sns.violinplot(x="day",y="total_bill",data=tips,palette="Set1")
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
#factorplot, catplot

# %%
sns.factorplot(x="day",y="total_bill",data=tips)
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.catplot(x="day",y="total_bill",data=tips)

# %%
sns.catplot(x="day",y="total_bill",data=tips,kind="bar")

# %%
sns.barplot(x="day",y="total_bill",data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(x="day",y="total_bill",data=tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
#matrix plot-heatmap,cluster map

# %%
flights = sns.load_dataset("flights")

# %%
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flights.corr()
# Out:
#                 year  passengers
# year        1.000000    0.921824
# passengers  0.921824    1.000000

# %%
sns.heatmap(flights.corr(),annot=True,cmap="coolwarm")
# Out:
# <AxesSubplot:>

# %%
new_flights=flights.pivot_table(values="passengers",index='month',columns='year')  #anaother way to show data

# %%
new_flights
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
sns.heatmap(new_flights)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.heatmap(new_flights,cmap="coolwarm",linecolor="black",linewidths=3)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.heatmap(new_flights,cmap="Set1",linecolor="black",linewidths=3)
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.clustermap(new_flights)

# %%
sns.clustermap(new_flights,standard_scale=1,cmap="Set1")

# %%
#grids

# %%
iris=sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
type(iris)
# Out:
# pandas.core.frame.DataFrame

# %%
iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
sns.PairGrid(iris)

# %%
import matplotlib.pyplot as plt
g=sns.PairGrid(iris)
g.map(plt.scatter)

# %%
g=sns.PairGrid(iris)
g.map_diag(plt.hist)

# %%
g=sns.PairGrid(iris)
g.map_diag(plt.hist)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot)

# %%
sns.pairplot(iris,hue="species",palette="Set1")

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
g=sns.FacetGrid(tips,col="time",row="smoker")

# %%
g=sns.FacetGrid(tips,col="time",row="smoker")
g.map(plt.hist,"total_bill")

# %%
g=sns.FacetGrid(tips,col="time",row="smoker",hue="sex")
g.map(plt.hist,"total_bill").add_legend()

# %%
sns.JointGrid(x="total_bill",y="tip",data=tips)

# %%
g=sns.JointGrid(x="total_bill",y="tip",data=tips)
g.plot(sns.regplot,sns.displot)

# %%
sns.lmplot(x="total_bill",y="tip",data=tips)

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
